# %%
# LLM is open source framework that helps in building LLM Applications. Ir provides modular components and 
# end to end tools that helps developers build complex AI Application.
# It provides modular components and end to end tools that helps developers build complex AI Applications, such as chatbots, RAGs etc.

# 1. Supports all major LLMs.
# 2. simplifies developing LLM Based applciation
# 3. integrations available for all major tools.
# 4. open source/actively developed.
# 5. support all major GenAI Cases.
