# %%
import streamlit as st

# %%
st.title("Restaurant Name Generator")
# Out:
# 2026-04-15 20:24:06.500 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-15 20:24:07.331
# ...
#   command:
#
#     streamlit run C:\Users\newta\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-04-15 20:24:07.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-15 20:24:07.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
